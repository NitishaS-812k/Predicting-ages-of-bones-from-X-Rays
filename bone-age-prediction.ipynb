# %% [markdown]
# This notebook is an attempt to predict bone age using Xception(pre trained model)<br>

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import tensorflow as tf
import datetime, os
import math
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Some Setup**<br>
# The cell below creates the pandas dataframes for training and testing.

# %%
#loading dataframes
train_df = pd.read_csv('/kaggle/input/rsna-bone-age/boneage-training-dataset.csv')
test_df = pd.read_csv('/kaggle/input/rsna-bone-age/boneage-test-dataset.csv')

#appending file extension to id column for both training and testing dataframes
train_df['id'] = train_df['id'].apply(lambda x: str(x)+'.png')
test_df['Case ID'] = test_df['Case ID'].apply(lambda x: str(x)+'.png') 

train_df.head()
# Out:
#          id  boneage   male
# 0  1377.png      180  False
# 1  1378.png       12  False
# 2  1379.png       94  False
# 3  1380.png      120   True
# 4  1381.png       82  False

# %% [markdown]
# **Some EDA and feature engineering follow**

# %%
#finding out the number of male and female children in the dataset
#creating a new column called gender to keep the gender of the child as a string
train_df['gender'] = train_df['male'].apply(lambda x: 'male' if x else 'female')
print(train_df['gender'].value_counts())
sns.countplot(x = train_df['gender'])
# Out:
# male      6833
# female    5778
# Name: gender, dtype: int64

# %%
#oldest child in the dataset
print('MAX age: ' + str(train_df['boneage'].max()) + ' months')

#youngest child in the dataset
print('MIN age: ' + str(train_df['boneage'].min()) + ' months')

#mean age is
mean_bone_age = train_df['boneage'].mean()
print('mean: ' + str(mean_bone_age))

#median bone age
print('median: ' +str(train_df['boneage'].median()))

#standard deviation of boneage
std_bone_age = train_df['boneage'].std()

#models perform better when features are normalised to have zero mean and unity standard deviation
#using z score for the training
train_df['bone_age_z'] = (train_df['boneage'] - mean_bone_age)/(std_bone_age)

print(train_df.head())
# Out:
# MAX age: 228 months
# MIN age: 1 months
# mean: 127.3207517246848
# median: 132.0
#          id  boneage   male  gender  bone_age_z
# 0  1377.png      180  False  female    1.279181
# 1  1378.png       12  False  female   -2.800269
# 2  1379.png       94  False  female   -0.809109
# 3  1380.png      120   True    male   -0.177766
# 4  1381.png       82  False  female   -1.100498

# %%
#plotting a histogram for bone ages
train_df['boneage'].hist(color = 'green')
plt.xlabel('Age in months')
plt.ylabel('Number of children')
plt.title('Number of children in each age group')
# Out:
# Text(0.5, 1.0, 'Number of children in each age group')

# %%
train_df['bone_age_z'].hist(color = 'violet')
plt.xlabel('bone age z score')
plt.ylabel('Number of children')
plt.title('Relationship between number of children and bone age z score')
# Out:
# Text(0.5, 1.0, 'Relationship between number of children and bone age z score')

# %%
#Relationship between age and gender with a categorical scatter plot (swarmplot)
sns.swarmplot(x = train_df['gender'], y = train_df['boneage'])

# %%
#distribution of age within each gender 
male = train_df[train_df['gender'] == 'male']
female = train_df[train_df['gender'] == 'female']
fig, ax = plt.subplots(2,1)
ax[0].hist(male['boneage'], color = 'blue')
ax[0].set_ylabel('Number of boys')
ax[1].hist(female['boneage'], color = 'red')
ax[1].set_xlabel('Age in months')
ax[1].set_ylabel('Number of girls')
fig.set_size_inches((10,7))

# %%
#splitting train dataframe into traininng and validation dataframes
df_train, df_valid = train_test_split(train_df, test_size = 0.2, random_state = 0)

# %% [markdown]
# Looking into the dataset...

# %%
import matplotlib.image as mpimg
for filename, boneage, gender in train_df[['id','boneage','gender']].sample(4).values:
    img = mpimg.imread('/kaggle/input/rsna-bone-age/boneage-training-dataset/boneage-training-dataset/'+ filename)
    plt.imshow(img)
    plt.title('Image name:{}  Bone age: {} years  Gender: {}'.format(filename, boneage/12, gender))
    plt.show()

# %% [markdown]
# **Setting up Image Data Generators!**<br>
# We use image data generators for both training, testing and preprocessing of images. Validation set is already broken off from training set.

# %%
#library required for image preprocessing
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from  keras.applications.xception import preprocess_input 

#reducing down the size of the image 
img_size = 256

train_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input)
val_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input)

#train data generator
train_generator = train_data_generator.flow_from_dataframe(
    dataframe = df_train,
    directory = '/kaggle/input/rsna-bone-age/boneage-training-dataset/boneage-training-dataset',
    x_col= 'id',
    y_col= 'bone_age_z',
    batch_size = 32,
    seed = 42,
    shuffle = True,
    class_mode= 'other',
    flip_vertical = True,
    color_mode = 'rgb',
    target_size = (img_size, img_size))

#validation data generator
val_generator = val_data_generator.flow_from_dataframe(
    dataframe = df_valid,
    directory = '/kaggle/input/rsna-bone-age/boneage-training-dataset/boneage-training-dataset',
    x_col = 'id',
    y_col = 'bone_age_z',
    batch_size = 32,
    seed = 42,
    shuffle = True,
    class_mode = 'other',
    flip_vertical = True,
    color_mode = 'rgb',
    target_size = (img_size, img_size))

#test data generator
test_data_generator = ImageDataGenerator(preprocessing_function = preprocess_input)

test_generator = test_data_generator.flow_from_directory(
    directory = '/kaggle/input/rsna-bone-age/boneage-test-dataset',
    shuffle = True,
    class_mode = None,
    color_mode = 'rgb',
    target_size = (img_size,img_size))
# Out:
# Using TensorFlow backend.
# Found 10088 validated image filenames.
# Found 2523 validated image filenames.
# Found 200 images belonging to 1 classes.

# %%
test_X, test_Y = next(val_data_generator.flow_from_dataframe( 
                            df_valid, 
                            directory = '/kaggle/input/rsna-bone-age/boneage-training-dataset/boneage-training-dataset',
                            x_col = 'id',
                            y_col = 'bone_age_z', 
                            target_size = (img_size, img_size),
                            batch_size = 2523,
                            class_mode = 'other'
                            ))
# Out:
# Found 2523 validated image filenames.

# %% [markdown]
#  The function to plot training and validation error as a function of epochs

# %%
#plotting training and validation error
def plot_it(history):
    fig, ax = plt.subplots( figsize=(20,10))
    ax.plot(history.history['mae_in_months'])
    ax.plot(history.history['val_mae_in_months'])
    plt.title('Model Error')
    plt.ylabel('error')
    plt.xlabel('Epoch')
    plt.legend(['Train', 'Val'], loc='upper right')
    ax.grid(color='black')
    plt.show()

# %%
#function to return mae in months
from keras.metrics import mean_absolute_error
def mae_in_months(x_p, y_p):
    return mean_absolute_error((std_bone_age*x_p + mean_bone_age), (std_bone_age*y_p + mean_bone_age))

# %%
from tensorflow.keras.layers import GlobalMaxPooling2D, Dense,Flatten
from tensorflow.keras.callbacks import TensorBoard, ModelCheckpoint,EarlyStopping,ReduceLROnPlateau
from tensorflow.keras import Sequential

model_1 = tf.keras.applications.xception.Xception(input_shape = (img_size, img_size, 3),
                                           include_top = False,
                                           weights = 'imagenet')
model_1.trainable = True
model_2 = Sequential()
model_2.add(model_1)
model_2.add(GlobalMaxPooling2D())
model_2.add(Flatten())
model_2.add(Dense(512,activation = 'relu'))
model_2.add(Dense(10, activation = 'relu'))
model_2.add(Dense(1, activation = 'linear'))


#compile model
model_2.compile(loss ='mse', optimizer= 'adam', metrics = [mae_in_months] )

#model summary
model_2.summary()
# Out:
# Downloading data from https://github.com/fchollet/deep-learning-models/releases/download/v0.4/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83689472/83683744 [==============================] - 1s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# xception (Model)             (None, 8, 8, 2048)        20861480
# _________________________________________________________________
# global_max_pooling2d (Global (None, 2048)              0
# _________________________________________________________________
# flatten (Flatten)            (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 512)               1049088
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                5130
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 21,915,709
# Trainable params: 21,861,181
# Non-trainable params: 54,528
# _________________________________________________________________

# %%
# Load the TensorBoard notebook extension
# %load_ext tensorboard
logs_dir = '.\logs'
# %tensorboard --logdir {logs_dir}
# Out:
#       <iframe id="tensorboard-frame-1b1a7e16a0f6fb86" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-1b1a7e16a0f6fb86");
#           const url = new URL("/", window.location);
#           url.port = 6006;
#           frame.src = url;
#         })();
#       </script>

# %%
#early stopping
early_stopping = EarlyStopping(monitor='val_loss',
                              min_delta=0,
                              patience=30,
                              verbose=0, mode='auto')

#model checkpoint
mc = ModelCheckpoint('best_model.h5', monitor='val_loss', mode='min', save_best_only=True)

#tensorboard callback
logdir = os.path.join(logs_dir,datetime.datetime.now().strftime('%Y%m%d-%H%M%S'))
tensorboard_callback =  TensorBoard(logdir, histogram_freq = 1)

#reduce lr on plateau
red_lr_plat = ReduceLROnPlateau(monitor='val_loss', factor=0.1, patience=10, verbose=0, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

callbacks = [tensorboard_callback,early_stopping,mc, red_lr_plat]


#fit model
history = model_2.fit_generator(train_generator,
                            steps_per_epoch = 3,
                            validation_data = val_generator,
                            validation_steps = 1,
                            epochs = 200,
                            callbacks= callbacks)
history
# %tensorboard --logdir logs
plot_it(history)
# Out:
# Train for 3 steps, validate for 1 steps
# Epoch 1/200
# 3/3 [==============================] - 20s 7s/step - loss: 12.5322 - mae_in_months: 109.0474 - val_loss: 56.5821 - val_mae_in_months: 298.9182
# Epoch 2/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.9701 - mae_in_months: 32.4164 - val_loss: 62.8893 - val_mae_in_months: 308.1039
# Epoch 3/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.1941 - mae_in_months: 37.7721 - val_loss: 35.3941 - val_mae_in_months: 226.4408
# Epoch 4/200
# 3/3 [==============================] - 13s 4s/step - loss: 1.2784 - mae_in_months: 38.6243 - val_loss: 16.7070 - val_mae_in_months: 152.2358
# Epoch 5/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.0954 - mae_in_months: 33.3752 - val_loss: 9.3301 - val_mae_in_months: 110.7517
# Epoch 6/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.0040 - mae_in_months: 33.5018 - val_loss: 6.4202 - val_mae_in_months: 89.6821
# Epoch 7/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.1047 - mae_in_months: 33.3007 - val_loss: 4.9410 - val_mae_in_months: 76.7726
# Epoch 8/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.2660 - mae_in_months: 38.7640 - val_loss: 3.6010 - val_mae_in_months: 62.9237
# Epoch 9/200
# 3/3 [==============================] - 13s 4s/step - loss: 0.9873 - mae_in_months: 33.0703 - val_loss: 2.9433 - val_mae_in_months: 55.5346
# Epoch 10/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.9074 - mae_in_months: 33.5995 - val_loss: 2.5555 - val_mae_in_months: 50.9211
# Epoch 11/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.9695 - mae_in_months: 32.2419 - val_loss: 2.6489 - val_mae_in_months: 53.0141
# Epoch 12/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.9555 - mae_in_months: 32.4704 - val_loss: 3.6013 - val_mae_in_months: 66.9934
# Epoch 13/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.0899 - mae_in_months: 35.2217 - val_loss: 4.1222 - val_mae_in_months: 73.5979
# Epoch 14/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.9990 - mae_in_months: 32.9215 - val_loss: 4.2875 - val_mae_in_months: 74.9948
# Epoch 15/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.7443 - mae_in_months: 28.9793 - val_loss: 4.0891 - val_mae_in_months: 72.4751
# Epoch 16/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.9256 - mae_in_months: 31.8547 - val_loss: 2.6788 - val_mae_in_months: 55.4209
# Epoch 17/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.8244 - mae_in_months: 28.7861 - val_loss: 2.1361 - val_mae_in_months: 47.7333
# Epoch 18/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.9580 - mae_in_months: 31.9090 - val_loss: 1.6961 - val_mae_in_months: 40.3060
# Epoch 19/200
# 3/3 [==============================] - 13s 4s/step - loss: 0.8450 - mae_in_months: 29.8632 - val_loss: 1.2894 - val_mae_in_months: 36.2155
# Epoch 20/200
# 3/3 [==============================] - 12s 4s/step - loss: 1.0227 - mae_in_months: 33.7540 - val_loss: 0.9547 - val_mae_in_months: 33.8334
# Epoch 21/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.6631 - mae_in_months: 26.2058 - val_loss: 0.9375 - val_mae_in_months: 33.8782
# Epoch 22/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.7801 - mae_in_months: 27.7004 - val_loss: 0.9715 - val_mae_in_months: 34.5826
# Epoch 23/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.7488 - mae_in_months: 27.0246 - val_loss: 0.8671 - val_mae_in_months: 32.4453
# Epoch 24/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.6871 - mae_in_months: 24.5144 - val_loss: 0.8527 - val_mae_in_months: 32.7129
# Epoch 25/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.9241 - mae_in_months: 30.4643 - val_loss: 0.8771 - val_mae_in_months: 33.9712
# Epoch 26/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.8479 - mae_in_months: 29.4883 - val_loss: 0.8920 - val_mae_in_months: 34.2004
# Epoch 27/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.9179 - mae_in_months: 28.8498 - val_loss: 0.9387 - val_mae_in_months: 35.1325
# Epoch 28/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.7306 - mae_in_months: 27.4903 - val_loss: 1.0285 - val_mae_in_months: 36.8532
# Epoch 29/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.8409 - mae_in_months: 29.8530 - val_loss: 0.8653 - val_mae_in_months: 33.3978
# Epoch 30/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.7451 - mae_in_months: 26.5050 - val_loss: 1.0911 - val_mae_in_months: 36.1041
# Epoch 31/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.5549 - mae_in_months: 24.5620 - val_loss: 0.6843 - val_mae_in_months: 28.0727
# Epoch 32/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.5803 - mae_in_months: 25.0712 - val_loss: 0.6814 - val_mae_in_months: 27.1487
# Epoch 33/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.6291 - mae_in_months: 24.8280 - val_loss: 0.5220 - val_mae_in_months: 23.8633
# Epoch 34/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.6284 - mae_in_months: 25.9651 - val_loss: 0.5614 - val_mae_in_months: 24.8470
# Epoch 35/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.7038 - mae_in_months: 24.5213 - val_loss: 0.9415 - val_mae_in_months: 34.5849
# Epoch 36/200
# 3/3 [==============================] - 13s 4s/step - loss: 0.4809 - mae_in_months: 23.1972 - val_loss: 0.3802 - val_mae_in_months: 20.9804
# Epoch 37/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.6488 - mae_in_months: 26.2364 - val_loss: 0.4110 - val_mae_in_months: 22.0028
# Epoch 38/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.4414 - mae_in_months: 21.4045 - val_loss: 0.3936 - val_mae_in_months: 22.0956
# Epoch 39/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.4966 - mae_in_months: 21.7733 - val_loss: 1.0418 - val_mae_in_months: 34.9472
# Epoch 40/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.5312 - mae_in_months: 22.6255 - val_loss: 1.3108 - val_mae_in_months: 41.2763
# Epoch 41/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.3363 - mae_in_months: 19.0174 - val_loss: 1.5765 - val_mae_in_months: 46.3345
# Epoch 42/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.4188 - mae_in_months: 20.7059 - val_loss: 0.9310 - val_mae_in_months: 33.5022
# Epoch 43/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.3005 - mae_in_months: 16.2756 - val_loss: 0.9597 - val_mae_in_months: 34.3530
# Epoch 44/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.5117 - mae_in_months: 23.4428 - val_loss: 0.4301 - val_mae_in_months: 20.8459
# Epoch 45/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.5223 - mae_in_months: 23.0373 - val_loss: 0.3883 - val_mae_in_months: 19.9104
# Epoch 46/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.3766 - mae_in_months: 20.1022 - val_loss: 0.2803 - val_mae_in_months: 17.5446
# Epoch 47/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2786 - mae_in_months: 16.3568 - val_loss: 0.4634 - val_mae_in_months: 23.6680
# Epoch 48/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.3568 - mae_in_months: 19.1099 - val_loss: 0.6215 - val_mae_in_months: 27.5431
# Epoch 49/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1894 - mae_in_months: 13.8836 - val_loss: 0.4798 - val_mae_in_months: 23.9198
# Epoch 50/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.3554 - mae_in_months: 19.9191 - val_loss: 0.2514 - val_mae_in_months: 16.8979
# Epoch 51/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.2597 - mae_in_months: 16.3849 - val_loss: 0.2665 - val_mae_in_months: 16.9650
# Epoch 52/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2864 - mae_in_months: 17.9524 - val_loss: 0.3147 - val_mae_in_months: 19.9250
# Epoch 53/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.4002 - mae_in_months: 19.2486 - val_loss: 0.3442 - val_mae_in_months: 20.4780
# Epoch 54/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2356 - mae_in_months: 16.4985 - val_loss: 0.3094 - val_mae_in_months: 19.0769
# Epoch 55/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.2318 - mae_in_months: 16.0791 - val_loss: 0.2642 - val_mae_in_months: 17.6896
# Epoch 56/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.2503 - mae_in_months: 16.5486 - val_loss: 0.2681 - val_mae_in_months: 17.6094
# Epoch 57/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.1777 - mae_in_months: 13.5211 - val_loss: 0.2494 - val_mae_in_months: 16.7019
# Epoch 58/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2660 - mae_in_months: 16.7468 - val_loss: 0.2055 - val_mae_in_months: 15.4328
# Epoch 59/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.2678 - mae_in_months: 16.0801 - val_loss: 0.1914 - val_mae_in_months: 14.7552
# Epoch 60/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1951 - mae_in_months: 14.8240 - val_loss: 0.1876 - val_mae_in_months: 14.6313
# Epoch 61/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2043 - mae_in_months: 14.6535 - val_loss: 0.2069 - val_mae_in_months: 15.3462
# Epoch 62/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1960 - mae_in_months: 14.0702 - val_loss: 0.3653 - val_mae_in_months: 21.2824
# Epoch 63/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2539 - mae_in_months: 17.2713 - val_loss: 0.4673 - val_mae_in_months: 24.1865
# Epoch 64/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1596 - mae_in_months: 13.5900 - val_loss: 0.5108 - val_mae_in_months: 25.0262
# Epoch 65/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2454 - mae_in_months: 15.3032 - val_loss: 0.7906 - val_mae_in_months: 31.3635
# Epoch 66/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1720 - mae_in_months: 14.2530 - val_loss: 0.6550 - val_mae_in_months: 28.7844
# Epoch 67/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.2499 - mae_in_months: 16.6259 - val_loss: 0.1457 - val_mae_in_months: 12.7993
# Epoch 68/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.2444 - mae_in_months: 16.6137 - val_loss: 0.2561 - val_mae_in_months: 15.1905
# Epoch 69/200
# 3/3 [==============================] - 12s 4s/step - loss: 0.1734 - mae_in_months: 14.3692 - val_loss: 0.1402 - val_mae_in_months: 12.6940
# Epoch 70/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1764 - mae_in_months: 13.3612 - val_loss: 0.1901 - val_mae_in_months: 14.7395
# Epoch 71/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1845 - mae_in_months: 14.2615 - val_loss: 0.2085 - val_mae_in_months: 15.6058
# Epoch 72/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1443 - mae_in_months: 12.5933 - val_loss: 0.2215 - val_mae_in_months: 16.0160
# Epoch 73/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1293 - mae_in_months: 11.7801 - val_loss: 0.2317 - val_mae_in_months: 16.3556
# Epoch 74/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1917 - mae_in_months: 14.1427 - val_loss: 0.1814 - val_mae_in_months: 14.8367
# Epoch 75/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1754 - mae_in_months: 13.8767 - val_loss: 0.2151 - val_mae_in_months: 16.1488
# Epoch 76/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1964 - mae_in_months: 13.8632 - val_loss: 0.2368 - val_mae_in_months: 16.9386
# Epoch 77/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1422 - mae_in_months: 12.5522 - val_loss: 0.2827 - val_mae_in_months: 18.3283
# Epoch 78/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1358 - mae_in_months: 12.2098 - val_loss: 0.4341 - val_mae_in_months: 22.4185
# Epoch 79/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1801 - mae_in_months: 14.1114 - val_loss: 0.4646 - val_mae_in_months: 23.1049
# Epoch 80/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1577 - mae_in_months: 13.2235 - val_loss: 0.4336 - val_mae_in_months: 22.3293
# Epoch 81/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1597 - mae_in_months: 13.0140 - val_loss: 0.3859 - val_mae_in_months: 21.0705
# Epoch 82/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2157 - mae_in_months: 14.5812 - val_loss: 0.3326 - val_mae_in_months: 19.7608
# Epoch 83/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1196 - mae_in_months: 10.7289 - val_loss: 0.2803 - val_mae_in_months: 18.4677
# Epoch 84/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1600 - mae_in_months: 12.6569 - val_loss: 0.2509 - val_mae_in_months: 17.5494
# Epoch 85/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.2231 - mae_in_months: 15.1073 - val_loss: 0.2335 - val_mae_in_months: 16.9509
# Epoch 86/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1691 - mae_in_months: 13.6455 - val_loss: 0.2238 - val_mae_in_months: 16.5273
# Epoch 87/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1622 - mae_in_months: 13.0247 - val_loss: 0.2153 - val_mae_in_months: 16.0723
# Epoch 88/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1483 - mae_in_months: 13.1606 - val_loss: 0.2087 - val_mae_in_months: 15.6822
# Epoch 89/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1372 - mae_in_months: 12.4217 - val_loss: 0.2037 - val_mae_in_months: 15.4692
# Epoch 90/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1505 - mae_in_months: 12.9167 - val_loss: 0.2024 - val_mae_in_months: 15.4146
# Epoch 91/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1523 - mae_in_months: 12.6498 - val_loss: 0.2014 - val_mae_in_months: 15.3593
# Epoch 92/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.0976 - mae_in_months: 9.9063 - val_loss: 0.2006 - val_mae_in_months: 15.3279
# Epoch 93/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1661 - mae_in_months: 13.8642 - val_loss: 0.1995 - val_mae_in_months: 15.2663
# Epoch 94/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1362 - mae_in_months: 12.1912 - val_loss: 0.1988 - val_mae_in_months: 15.2391
# Epoch 95/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1719 - mae_in_months: 13.2533 - val_loss: 0.1976 - val_mae_in_months: 15.1861
# Epoch 96/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.2555 - mae_in_months: 16.4321 - val_loss: 0.1962 - val_mae_in_months: 15.1157
# Epoch 97/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1190 - mae_in_months: 11.0227 - val_loss: 0.1951 - val_mae_in_months: 15.0466
# Epoch 98/200
# 3/3 [==============================] - 11s 4s/step - loss: 0.1405 - mae_in_months: 12.5780 - val_loss: 0.1947 - val_mae_in_months: 15.0278
# Epoch 99/200
# 3/3 [==============================] - 10s 3s/step - loss: 0.1939 - mae_in_months: 14.5319 - val_loss: 0.1931 - val_mae_in_months: 14.9462
#       <iframe id="tensorboard-frame-587a2ef05cf1b413" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-587a2ef05cf1b413");
#           const url = new URL("/", window.location);
#           url.port = 6007;
#           frame.src = url;
#         })();
#       </script>

# %% [markdown]
# Evaluating the best saved model on the validation data and visualising results!!

# %%
model_2.load_weights('best_model.h5')
pred = mean_bone_age + std_bone_age*(model_2.predict(test_X, batch_size = 32, verbose = True))
test_months = mean_bone_age + std_bone_age*(test_Y)

ord_ind = np.argsort(test_Y)
ord_ind = ord_ind[np.linspace(0, len(ord_ind)-1, 8).astype(int)] # take 8 evenly spaced ones
fig, axs = plt.subplots(4, 2, figsize = (15, 30))
for (ind, ax) in zip(ord_ind, axs.flatten()):
    ax.imshow(test_X[ind, :,:,0], cmap = 'bone')
    ax.set_title('Age: %fY\nPredicted Age: %fY' % (test_months[ind]/12.0, 
                                                           pred[ind]/12.0))
    ax.axis('off')
fig.savefig('trained_image_predictions.png', dpi = 300)
# Out:
# 2523/2523 [==============================] - 10s 4ms/sample

# %%
fig, ax = plt.subplots(figsize = (7,7))
ax.plot(test_months, pred, 'r.', label = 'predictions')
ax.plot(test_months, test_months, 'b-', label = 'actual')
ax.legend(loc = 'upper right')
ax.set_xlabel('Actual Age (Months)')
ax.set_ylabel('Predicted Age (Months)')
# Out:
# Text(0, 0.5, 'Predicted Age (Months)')

# %% [markdown]
# **The plot deviates from the line at very old and very young ages probably because we have less examples for those cases in the dataset**

# %% [markdown]
# Predicting on test data, we obtain:

# %%
test_generator.reset()
y_pred = model_2.predict_generator(test_generator)
predicted = y_pred.flatten()
predicted_months = mean_bone_age + std_bone_age*(predicted)
filenames=test_generator.filenames
results=pd.DataFrame({"Filename":filenames,
                      "Predictions": predicted_months})
results.to_csv("results.csv",index=False)
